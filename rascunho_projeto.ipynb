# %% [markdown]
# [23:08, 12/10/2024] Isaac: aqui vai ficar as info sobre a automação do lançamento de comandas, acho que vou separar cada ap por uma caixa daqui
# loucura loucura loucura
# ---------------------
# [23:08, 12/10/2024] Isaac: # Inserir uma lista = list_0
# # Formatar lista descrita = list_ok = list([UH], [N_comanda], [procedencia_item/tipo], [itens], [quantidade])
# # Ler informações da lista
# For Item in lista_ok():
# # Lembrar de arrumar essas referencias (list_ok[item da lista])
#
# # mudança de planos ---->celula 2
#
#
# def lancamento():
#     Buscar IMG do "UH"             na tela
#     clicar "UH"
#     buscar IMG "extrato de conta"  na tela
#     clicar "extrato de conta"
#     buscar IMG "Extra"             na tela
#     if error.cantfindimage():
#         buscar IMG "Particular"    na tela
#
# def lancar_item():
#
#     buscar IMG "Lançar item"       na tela
#     clicar "lançar item"
#
#     # número da comanda
#     buscar IMG "N_da_comanda"
#     clicar "N_da_comanda"
#     preencher com "[N_comanda]"
#
#     # tipo do item("bar recepção", "consumação", "frigobar")
#     buscar IMG "Procedencia_item"  na tela
#     clicar "Procedencia_item"
#     preencher com "[Procedencia_item/tipo]"
#
#     # items
#     buscar IMG "Novo_Item"         na tela
#     clicar "Novo_Item"
#     preencher com "[itens]"
#
#     # quantidade de items
#     buscar IMG "QNTD_ITEM"         na tela
#     clicar "QNTD_ITEM"
#     preencher com "[quantidade]"
#
#     buscar "Salvar"                na tela
#     clicar "Salvar"
#
#
#     buscar "Mapa de UH's"          na tela
#     clicar "Mapa de UH's"

# %% [markdown]
# # Inserir UH
# # inserir pdv
# # inserir item
# # inserir qntd_item
# #
#
# import pyautogui   as                              pag
# from pyautogui import  click                  as    click
# from pyautogui import  locateCenterOnScreen   as    buscar
# from time      import  sleep                  as    sleep
#
# pag.sleep(0.3)
# pag.FAILSAFE = True
#
# UH = str(input("número do UH: "))
# for "" in UH():
#     do this: trlalala
#
# N_comanda = str(input("número da comanda: "))
#
# pdv = str(input("PDV: "))
#
# item = str(input("Item: "))
#
# qntd_item = str(input("quantidade do item: "))
#
#
# lancar_isso_isso = list[UH, N_comanda, pdv, item, qntd_item]003
# print(lancar_isso_isso)
